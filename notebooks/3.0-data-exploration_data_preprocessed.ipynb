# %%
import pandas as pd
import numpy as np
from pathlib import Path
import os
import logging
from glob import glob

dfs = ['x_train', 'x_test', 'y_train', 'y_test']

for value in dfs:
    globals()[f'df{value}'] = pd.read_csv(f'../data/preprocessed/{value}.csv')
    print(f'Loaded {value} with shape: {globals()[f"df{value}"].shape}')
# Out:
# Loaded x_train with shape: (129044, 28)
# Loaded x_test with shape: (55305, 28)
# Loaded y_train with shape: (129044, 1)
# Loaded y_test with shape: (55305, 1)
